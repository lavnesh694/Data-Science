# %%
import pandas as pd

# %%
data=pd.read_csv("zomato.csv",encoding='latin1')

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
data.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
data.shape
# Out:
# (9551, 21)

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9546    False
# 9547    False
# 9548    False
# 9549    False
# 9550    False
# Length: 9551, dtype: bool

# %%
data=data.drop_duplicates()
data.shape
# Out:
# (9551, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
data['City']
# Out:
# 0            Makati City
# 1            Makati City
# 2       Mandaluyong City
# 3       Mandaluyong City
# 4       Mandaluyong City
#               ...
# 9546           ÛÁstanbul
# 9547           ÛÁstanbul
# 9548           ÛÁstanbul
# 9549           ÛÁstanbul
# 9550           ÛÁstanbul
# Name: City, Length: 9551, dtype: object

# %%
data=data.apply(lambda x:x.str.lower() if x.dtype==object else x)

# %%
data['City']
# Out:
# 0            makati city
# 1            makati city
# 2       mandaluyong city
# 3       mandaluyong city
# 4       mandaluyong city
#               ...
# 9546           ûástanbul
# 9547           ûástanbul
# 9548           ûástanbul
# 9549           ûástanbul
# 9550           ûástanbul
# Name: City, Length: 9551, dtype: object

# %%
data.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
data['Locality'].value_counts().head(10)
# Out:
# Locality
# connaught place        122
# rajouri garden          99
# shahdara                87
# defence colony          86
# malviya nagar           85
# pitampura               85
# mayur vihar phase 1     84
# rajinder nagar          81
# safdarjung              80
# satyaniketan            79
# Name: count, dtype: int64

# %%
data['Restaurant Name'].value_counts().head(10)
# Out:
# Restaurant Name
# cafe coffee day     83
# domino's pizza      79
# subway              63
# green chick chop    51
# mcdonald's          48
# keventers           34
# pizza hut           30
# giani               29
# baskin robbins      28
# barbeque nation     26
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
round(data['Has Online delivery'].value_counts(normalize=True)*100,3)
# Out:
# Has Online delivery
# no     74.338
# yes    25.662
# Name: proportion, dtype: float64

# %%
data['Aggregate rating'].value_counts().sort_index()
# Out:
# Aggregate rating
# 0.0    2148
# 1.8       1
# 1.9       2
# 2.0       7
# 2.1      15
# 2.2      27
# 2.3      47
# 2.4      87
# 2.5     110
# 2.6     191
# 2.7     250
# 2.8     315
# 2.9     381
# 3.0     468
# 3.1     519
# 3.2     522
# 3.3     483
# 3.4     498
# 3.5     480
# 3.6     458
# 3.7     427
# 3.8     400
# 3.9     335
# 4.0     266
# 4.1     274
# 4.2     221
# 4.3     174
# 4.4     144
# 4.5      95
# 4.6      78
# 4.7      42
# 4.8      25
# 4.9      61
# Name: count, dtype: int64

# %%
data['Average Cost for two'].value_counts().head(10)
# Out:
# Average Cost for two
# 500    900
# 300    897
# 400    857
# 200    687
# 600    652
# 250    461
# 350    457
# 700    403
# 150    367
# 100    353
# Name: count, dtype: int64

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          le petit souffle           162       makati city
# 1           6304287          izakaya kikufuji           162       makati city
# 2           6300002    heat - edsa shangri-la           162  mandaluyong city
# 3           6318506                      ooma           162  mandaluyong city
# 4           6314302               sambo kojin           162  mandaluyong city
# ...             ...                       ...           ...               ...
# 9546        5915730              namlû± gurme           208         ûástanbul
# 9547        5908749             ceviz aûôacû±           208         ûástanbul
# 9548        5915807                     huqqa           208         ûástanbul
# 9549        5916112              aôôk kahve           208         ûástanbul
# 9550        5927402  walter's coffee roastery           208         ûástanbul
#
# ...

# %%
import pandas as pd

# %%
data=pd.read_csv("zomato.csv",encoding='latin1')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# # top 10 places to where most of the retaurant are there

# %%
df['Locality'].value_counts().head(10) # top 10 locations where most of the restuarnts
# Out:
# Locality
# Connaught Place        122
# Rajouri Garden          99
# Shahdara                87
# Defence Colony          86
# Malviya Nagar           85
# Pitampura               85
# Mayur Vihar Phase 1     84
# Rajinder Nagar          81
# Safdarjung              80
# Satyaniketan            79
# Name: count, dtype: int64

# %% [markdown]
# # Most common Cousines

# %%
l=[]
df['Cuisines'].dropna().apply(lambda x:l.extend([c.strip() for c in x.split(',')]));

# %%
from collections import Counter

most_common_cousine=Counter(l).most_common(10)

# %%
most_common_cousine
# Out:
# [('North Indian', 3960),
#  ('Chinese', 2735),
#  ('Fast Food', 1986),
#  ('Mughlai', 995),
#  ('Italian', 764),
#  ('Bakery', 745),
#  ('Continental', 736),
#  ('Cafe', 703),
#  ('Desserts', 653),
#  ('South Indian', 636)]

# %% [markdown]
# # Distribution of online odering

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
round(df['Has Online delivery'].value_counts(normalize=True)*100,1)
# Out:
# Has Online delivery
# No     74.3
# Yes    25.7
# Name: proportion, dtype: float64

# %% [raw]
# ->THis means that there is 75 % people don't believe in online delivery

# %%
import matplotlib.pyplot as plt

# %%
label=['Yes','No']
count=[25.7,74.3]
plt.style.use('dark_background')

plt.pie(count,textprops={'fontweight':'bold'},
        labels=label,explode=[0.1,0],autopct="%1.1f%%", colors=['lightcoral', 'lightgreen'], shadow=True,wedgeprops={'edgecolor':"pink",'linewidth':3})
plt.grid(True)
plt.title("Online delivery distribution")
# Out:
# Text(0.5, 1.0, 'Online delivery distribution')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.columns=df.columns.str.strip().str.lower().str.replace(' ','_')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   restaurant_id         9551 non-null   int64
#  1   restaurant_name       9551 non-null   object
#  2   country_code          9551 non-null   int64
#  3   city                  9551 non-null   object
#  4   address               9551 non-null   object
#  5   locality              9551 non-null   object
#  6   locality_verbose      9551 non-null   object
#  7   longitude             9551 non-null   float64
#  8   latitude              9551 non-null   float64
#  9   cuisines              9542 non-null   object
#  10  average_cost_for_two  9551 non-null   int64
#  11  currency              9551 non-null   object
#  12  has_table_booking     9551 non-null   object
#  13  has_online_delivery   9551 non-null   object
#  14  is_delivering_now     9551 non-null   object
# ...

# %%
most_costly=df[df['average_cost_for_two']==df['average_cost_for_two'].max()]
less_costly=df[df['average_cost_for_two']==df['average_cost_for_two'].min()]

# %%
# Out:
#       restaurant_id           restaurant_name  country_code              city  \
# 0                84          Le Petit Souffle           162       Makati City
# 1                84          Izakaya Kikufuji           162       Makati City
# 2                84    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3                84                      Ooma           162  Mandaluyong City
# 4                84               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546             84              NamlÛ± Gurme           208         ÛÁstanbul
# 9547             84             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548             84                     Huqqa           208         ÛÁstanbul
# 9549             84              Aôôk Kahve           208         ÛÁstanbul
# 9550             84  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df['restaurant_id']=data['Restaurant ID']

# %%
df
# Out:
#       restaurant_id           restaurant_name  country_code              city  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.query('average_cost_for_two')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 df.query('average_cost_for_two')
#
# File ~\anaconda3\envs\python_practice\Lib\site-packages\pandas\core\frame.py:4826, in DataFrame.query(self, expr, inplace, **kwargs)
#    4823 res = self.eval(expr, **kwargs)
#    4825 try:
# -> 4826     result = self.loc[res]
#    4827 except ValueError:
#    4828     # when res is multi-dimensional loc raises, but this is sometimes a
#    4829     # valid query
#    4830     result = self[res]
#
# File ~\anaconda3\envs\python_practice\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...
