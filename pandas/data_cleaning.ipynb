# %%
import pandas as pd

# %%
data=pd.read_csv("data_cleaning_sample.csv")

# %%
data
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
data.isnull()
# Out:
#     Name    Age   City  Gender  Email  Join Date
# 0  False  False  False   False  False      False
# 1  False   True  False   False  False      False
# 2  False  False  False   False  False      False
# 3  False   True  False   False  False      False
# 4  False  False  False   False  False      False
# 5   True  False  False   False  False       True
# 6  False  False  False   False  False      False
# 7  False  False  False   False  False      False
# 8  False   True  False   False  False      False

# %%
data.isnull().sum()
# Out:
# Name         1
# Age          3
# City         0
# Gender       0
# Email        0
# Join Date    1
# dtype: int64

# %%
data.dropna() # remove thr row with any missing values
# Out:
#     Name   Age         City Gender              Email   Join Date
# 0  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4  David  22.0       Mumbai      M  david@example.com  12-11-2019
# 6  Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7  Alice  25.0     New York      F  alice@example.com  01-05-2021

# %%
data.dropna(axis=1) # drop columns with any missing values
# Out:
#           City Gender              Email
# 0     New York      F  alice@example.com
# 1        Delhi      M    charlie@example
# 2  Los Angeles      M    bob@example.com
# 3        Delhi      M    charlie@example
# 4       Mumbai      M  david@example.com
# 5        Delhi      F     eve@domain.com
# 6     New York      F  alice@example.com
# 7     New York      F  alice@example.com
# 8        Delhi      M    charlie@example

# %%
data.fillna(0)
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   0.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   0.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5        0  28.0        Delhi      F     eve@domain.com           0
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   0.0        Delhi      M    charlie@example  20-07-2021

# %%
df=data
round(df["Age"].fillna(df['Age'].mean()),3)
# Out:
# 0    25.000
# 1    25.833
# 2    30.000
# 3    25.833
# 4    22.000
# 5    28.000
# 6    25.000
# 7    25.000
# 8    25.833
# Name: Age, dtype: float64

# %%
df.fillna(method="ffill")
# Out:
# C:\Users\lavne\AppData\Local\Temp\ipykernel_13928\3944122520.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill")
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    David  28.0        Delhi      F     eve@domain.com  12-11-2019
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  25.0        Delhi      M    charlie@example  20-07-2021

# %%
df.fillna(method="bfill")
# Out:
# C:\Users\lavne\AppData\Local\Temp\ipykernel_13928\3896554658.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="bfill")
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  22.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    Alice  28.0        Delhi      F     eve@domain.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.ffill()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie  25.0        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie  30.0        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5    David  28.0        Delhi      F     eve@domain.com  12-11-2019
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie  25.0        Delhi      M    charlie@example  20-07-2021

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df.drop_duplicates()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.duplicated(subset=["Name","Age"])
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# 7     True
# 8     True
# dtype: bool

# %%
df['Name'].str.lower()
# Out:
# 0      alice
# 1    charlie
# 2        bob
# 3    charlie
# 4      david
# 5        NaN
# 6      alice
# 7      alice
# 8    charlie
# Name: Name, dtype: object

# %%
df["Email"].str.split("@")
# Out:
# 0    [alice, example.com]
# 1      [charlie, example]
# 2      [bob, example.com]
# 3      [charlie, example]
# 4    [david, example.com]
# 5       [eve, domain.com]
# 6    [alice, example.com]
# 7    [alice, example.com]
# 8      [charlie, example]
# Name: Email, dtype: object

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
type(df['Join Date'])
# Out:
# pandas.core.series.Series

# %%
df['Join Date']=pd.to_datetime(df['Join Date'],dayfirst=True)

# %%
df['Join Date']

# %%
df2=df.dropna().copy()

# %%
df2
# Out:
#     Name   Age         City Gender              Email  Join Date
# 0  Alice  25.0     New York      F  alice@example.com 2021-05-01
# 2    Bob  30.0  Los Angeles      M    bob@example.com 2020-06-15
# 4  David  22.0       Mumbai      M  david@example.com 2019-11-12
# 6  Alice  25.0     New York      F  alice@example.com 2021-05-01
# 7  Alice  25.0     New York      F  alice@example.com 2021-05-01

# %%
df2['Age']=df2['Age'].astype(int)

# %%
type(df2['Age'])
# Out:
# pandas.core.series.Series

# %%
df2.info
# Out:
# <bound method DataFrame.info of     Name  Age         City Gender              Email  Join Date
# 0  Alice   25     New York      F  alice@example.com 2021-05-01
# 2    Bob   30  Los Angeles      M    bob@example.com 2020-06-15
# 4  David   22       Mumbai      M  david@example.com 2019-11-12
# 6  Alice   25     New York      F  alice@example.com 2021-05-01
# 7  Alice   25     New York      F  alice@example.com 2021-05-01>

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 0 to 7
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       5 non-null      object
#  1   Age        5 non-null      int32
#  2   City       5 non-null      object
#  3   Gender     5 non-null      object
#  4   Email      5 non-null      object
#  5   Join Date  5 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int32(1), object(4)
# memory usage: 260.0+ bytes

# %%
df['Age Group']=df["Age"].apply(lambda x:"Adult" if x>=18 else "baccha")

# %%
df
# Out:
#       Name   Age         City Gender              Email  Join Date Age Group
# 0    Alice  25.0     New York      F  alice@example.com 2021-05-01     Adult
# 1  Charlie   NaN        Delhi      M    charlie@example 2021-07-20    baccha
# 2      Bob  30.0  Los Angeles      M    bob@example.com 2020-06-15     Adult
# 3  Charlie   NaN        Delhi      M    charlie@example 2021-07-20    baccha
# 4    David  22.0       Mumbai      M  david@example.com 2019-11-12     Adult
# 5      NaN  28.0        Delhi      F     eve@domain.com        NaT     Adult
# 6    Alice  25.0     New York      F  alice@example.com 2021-05-01     Adult
# 7    Alice  25.0     New York      F  alice@example.com 2021-05-01     Adult
# 8  Charlie   NaN        Delhi      M    charlie@example 2021-07-20    baccha

# %%
mapi={"F":"Female","M":"Male"}
df['Gender']=df['Gender'].map(mapi)
df
# Out:
#       Name   Age         City  Gender              Email  Join Date Age Group
# 0    Alice  25.0     New York  Female  alice@example.com 2021-05-01     Adult
# 1  Charlie   NaN        Delhi    Male    charlie@example 2021-07-20    baccha
# 2      Bob  30.0  Los Angeles    Male    bob@example.com 2020-06-15     Adult
# 3  Charlie   NaN        Delhi    Male    charlie@example 2021-07-20    baccha
# 4    David  22.0       Mumbai    Male  david@example.com 2019-11-12     Adult
# 5      NaN  28.0        Delhi  Female     eve@domain.com        NaT     Adult
# 6    Alice  25.0     New York  Female  alice@example.com 2021-05-01     Adult
# 7    Alice  25.0     New York  Female  alice@example.com 2021-05-01     Adult
# 8  Charlie   NaN        Delhi    Male    charlie@example 2021-07-20    baccha

# %%
df['City']=df['City'].replace({"Delhi":"NEW_DELHI"})
df
# Out:
#       Name   Age         City  Gender              Email  Join Date Age Group
# 0    Alice  25.0     New York  Female  alice@example.com 2021-05-01     Adult
# 1  Charlie   NaN    NEW_DELHI    Male    charlie@example 2021-07-20    baccha
# 2      Bob  30.0  Los Angeles    Male    bob@example.com 2020-06-15     Adult
# 3  Charlie   NaN    NEW_DELHI    Male    charlie@example 2021-07-20    baccha
# 4    David  22.0       Mumbai    Male  david@example.com 2019-11-12     Adult
# 5      NaN  28.0    NEW_DELHI  Female     eve@domain.com        NaT     Adult
# 6    Alice  25.0     New York  Female  alice@example.com 2021-05-01     Adult
# 7    Alice  25.0     New York  Female  alice@example.com 2021-05-01     Adult
# 8  Charlie   NaN    NEW_DELHI    Male    charlie@example 2021-07-20    baccha
