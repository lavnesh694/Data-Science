# %%
import pandas

# %%
conda install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# # All requested packages already installed.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.3.1

# %%
import pandas as pd

# %%
s=pd.Series([10,20,30,40],index=["lavnesh","john","deepak","aman"])
s
# Out:
# lavnesh    10
# john       20
# deepak     30
# aman       40
# dtype: int64

# %%
data_frame={
    'name':['lavi','babu','bhau'],
     'age':[10,20,30],
      'roll_no':[1,2,3]

}

# %%
df=pd.DataFrame(data_frame)

# %%
df
# Out:
#    name  age  roll_no
# 0  lavi   10        1
# 1  babu   20        2
# 2  bhau   30        3

# %%
data=[['lavnesh',100],['deep',5],['fddf',55]]

# %%
pd.DataFrame(data,columns=['name','marks'])
# Out:
#       name  marks
# 0  lavnesh    100
# 1     deep      5
# 2     fddf     55

# %%
import numpy as np

# %%
conda install openpyxl
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\lavne\anaconda3\envs\python_practice
#
#   added / updated specs:
#     - openpyxl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openpyxl-3.1.5             |  py311h827c3e9_1         672 KB
#     ------------------------------------------------------------
#                                            Total:         672 KB
#
# The following NEW packages will be INSTALLED:
#
#   et_xmlfile         pkgs/main/win-64::et_xmlfile-1.1.0-py311haa95532_0
#   openpyxl           pkgs/main/win-64::openpyxl-3.1.5-py311h827c3e9_1
#
#
#
# ...
#
# openpyxl-3.1.5       | 672 KB    |            |   0%
# openpyxl-3.1.5       | 672 KB    | 2          |   2%
# openpyxl-3.1.5       | 672 KB    | ########## | 100%
# openpyxl-3.1.5       | 672 KB    | ########## | 100%
#
#
#
# ...

# %%
data=np.array([[1,2],[3,4]])
df=pd.DataFrame(data,columns=['a','b'])
df
# Out:
#    a  b
# 0  1  2
# 1  3  4

# %%
pd.read_csv("data.csv")
# Out:
#       name school  marks
# 0  lavnesh   kvsl     80
# 1   deepak   kvdl     90
# 2   pankaj   kvpl    100
# 3     alex    fdg     75
# 4     jasi  gfdgd     86
# 5    shubu    fgd     85
# 6    rishi  gfdgd     89

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("student_detail.xlsx")

# %%
df
# Out:
#      s.no                            Username                 Name  \
# 0       1    ankur.sharma.cse.2021@miet.ac.in         Ankur Sharma
# 1       2    abhay.sharma.cse.2021@miet.ac.in        Abhay Sharma
# 2       3  abhishek.malik.cse.2021@miet.ac.in       Abhishek malik
# 3       4    akshay.yadav.cse.2021@miet.ac.in         AKSHAY YADAV
# 4       5      aman.rathi.cse.2021@miet.ac.in           Aman Rathi
# ..    ...                                 ...                  ...
# 304   305     vineet.kumar.it.2021@miet.ac.in  Vineet Kumar Singh
# 305   306    vineet.panwar.it.2021@miet.ac.in       Vineet panwar
# 306   307     vipul.bansal.it.2021@miet.ac.in        Vipul Bansal
# 307   308      vipul.tyagi.it.2021@miet.ac.in          Vipul Tyagi
# 308   309            nancys28072003@gmail.com               Nainsi
#
#      mobile no. parents mobile no.    Roll Number Course / Branch  \
# 0    7037941222         7037941222  2100680100063   B.Tech ( CSE)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   s.no                                  309 non-null    int64
#  1   Username                              309 non-null    object
#  2   Name                                  309 non-null    object
#  3   mobile no.                            309 non-null    int64
#  4   parents mobile no.                    272 non-null    object
#  5   Roll Number                           309 non-null    int64
#  6   Course / Branch                       309 non-null    object
#  7   profile                               309 non-null    object
#  8   Gender
#                                309 non-null    object
#  9   LOCATION                              309 non-null    object
#  10  Passing Year                          309 non-null    int64
# ...

# %%
df['profile'].value_counts()
# Out:
# profile
# Data Analyst                       110
# Python Developer                   106
# IT Consultant                       36
# AI/ML Engineer                      31
# Business Development Excecutive     21
# Customer Support                     5
# Name: count, dtype: int64

# %%
df['new_col']=df['Username'].apply(lambda x:x.split('@')[0])

# %%
df['new_col']
# Out:
# 0        ankur.sharma.cse.2021
# 1        abhay.sharma.cse.2021
# 2      abhishek.malik.cse.2021
# 3        akshay.yadav.cse.2021
# 4          aman.rathi.cse.2021
#                 ...
# 304       vineet.kumar.it.2021
# 305      vineet.panwar.it.2021
# 306       vipul.bansal.it.2021
# 307        vipul.tyagi.it.2021
# 308             nancys28072003
# Name: new_col, Length: 309, dtype: object

# %%
l=[]
other=[]
df['new_col']=df['new_col'].apply(lambda x:l.append(x) if 'cseds' in x else other.append(x))

# %%
# Out:
# ['nikita.tiwari.cseds.2021',
#  'aman.upadhayay.cseds.2021',
#  'aastha.malik.cseds.2021',
#  'aditya.dabas.cseds.2021',
#  'aman.chhabra.cseds.2021',
#  'ananya.dudeja.cseds.2021',
#  'arthav.kumar.cseds.2021',
#  'ayush.chaudhary.cseds.2021',
#  'krishna.kumar.cseds.2021',
#  'lavnesh.kumar.cseds.2021',
#  'nipun.singhal.cseds.2021',
#  'samarth.kaushik.cseds.2021',
#  'shobit.choudhary.cseds.2021',
#  'shubham.yadav.cseds.2021',
#  'sneha.s.cseds.2021',
#  'sparsh.kansal.cseds.2021',
#  'tushar.goel.cseds.2021',
#  'vansh.gupta.cseds.2021',
#  'yashika.yadav.cseds.2021',
#  'akhil.kumar.csedsl.2021',
#  'siddhant.kumar.csedsl.2021',
#  'anshul.tyagi.cseds.2021']

# %%
a="cseds"
df2=df[df['Username'].str.contains(a)]

# %%
df2.shape
# Out:
# (22, 20)

# %%
df2
# Out:
#      s.no                                Username               Name  \
# 237   238     nikita.tiwari.cseds.2021@miet.ac.in      NIKITA TIWARI
# 238   239    aman.upadhayay.cseds.2021@miet.ac.in     Aman Upadhayay
# 239   240      aastha.malik.cseds.2021@miet.ac.in       Aastha Malik
# 240   241      aditya.dabas.cseds.2021@miet.ac.in      Aditya dabas
# 241   242      aman.chhabra.cseds.2021@miet.ac.in       Aman chhabra
# 242   243     ananya.dudeja.cseds.2021@miet.ac.in      Ananya Dudeja
# 243   244      arthav.kumar.cseds.2021@miet.ac.in      Arthav Kumar
# 244   245   ayush.chaudhary.cseds.2021@miet.ac.in   Ayush Chaudhary
# 246   247     krishna.kumar.cseds.2021@miet.ac.in     Krishna kumar
# 247   248     lavnesh.kumar.cseds.2021@miet.ac.in      Lavnesh kumar
# 248   249     nipun.singhal.cseds.2021@miet.ac.in      Nipun Singhal
# 249   250   samarth.kaushik.cseds.2021@miet.ac.in    Samarth Kaushik
# 250   251  shobit.choudhary.cseds.2021@miet.ac.in  Shobit Choudhary
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 20 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   s.no                                  309 non-null    int64
#  1   Username                              309 non-null    object
#  2   Name                                  309 non-null    object
#  3   mobile no.                            309 non-null    int64
#  4   parents mobile no.                    272 non-null    object
#  5   Roll Number                           309 non-null    int64
#  6   Course / Branch                       309 non-null    object
#  7   profile                               309 non-null    object
#  8   Gender
#                                309 non-null    object
#  9   LOCATION                              309 non-null    object
#  10  Passing Year                          309 non-null    int64
# ...

# %%
df.column
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26888\1071123522.py in ?()
# ----> 1 df.column
#
# ~\anaconda3\envs\python_practice\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %%
df2
# Out:
#      s.no                                Username               Name  \
# 237   238     nikita.tiwari.cseds.2021@miet.ac.in      NIKITA TIWARI
# 238   239    aman.upadhayay.cseds.2021@miet.ac.in     Aman Upadhayay
# 239   240      aastha.malik.cseds.2021@miet.ac.in       Aastha Malik
# 240   241      aditya.dabas.cseds.2021@miet.ac.in      Aditya dabas
# 241   242      aman.chhabra.cseds.2021@miet.ac.in       Aman chhabra
# 242   243     ananya.dudeja.cseds.2021@miet.ac.in      Ananya Dudeja
# 243   244      arthav.kumar.cseds.2021@miet.ac.in      Arthav Kumar
# 244   245   ayush.chaudhary.cseds.2021@miet.ac.in   Ayush Chaudhary
# 246   247     krishna.kumar.cseds.2021@miet.ac.in     Krishna kumar
# 247   248     lavnesh.kumar.cseds.2021@miet.ac.in      Lavnesh kumar
# 248   249     nipun.singhal.cseds.2021@miet.ac.in      Nipun Singhal
# 249   250   samarth.kaushik.cseds.2021@miet.ac.in    Samarth Kaushik
# 250   251  shobit.choudhary.cseds.2021@miet.ac.in  Shobit Choudhary
# ...

# %%
df.columns
# Out:
# Index(['s.no', 'Username', 'Name', 'mobile no.', 'parents mobile no.',
#        'Roll Number', 'Course / Branch', 'profile', 'Gender\n', 'LOCATION',
#        'Passing Year', ' X % ', ' XII % ', 'Diploma%',
#        'B.Tech CSIT/All Allied branches/ UG%', 'Name of the college',
#        'Do you have any active backlog?', 'Your home town?', 'Upload Resume',
#        'new_col'],
#       dtype='object')

# %%
df['Gender\n'].value_counts()
# Out:
# Gender\n
# MALE      211
# FEMALE     98
# Name: count, dtype: int64

# %%
df.columns=df.columns.str.split(' ')

# %%
df.columns
# Out:
# Index(['s.no', 'Username', 'Name', 'mobile no.', 'parents mobile no.',
#        'Roll Number', 'Course / Branch', 'profile', 'Gender\n', 'LOCATION',
#        'Passing Year', ' X % ', ' XII % ', 'Diploma%',
#        'B.Tech CSIT/All Allied branches/ UG%', 'Name of the college',
#        'Do you have any active backlog?', 'Your home town?', 'Upload Resume',
#        'new_col'],
#       dtype='object')

# %%
df=pd.read_excel("student_detail.xlsx")

# %%
df
# Out:
#      s.no                            Username                 Name  \
# 0       1    ankur.sharma.cse.2021@miet.ac.in         Ankur Sharma
# 1       2    abhay.sharma.cse.2021@miet.ac.in        Abhay Sharma
# 2       3  abhishek.malik.cse.2021@miet.ac.in       Abhishek malik
# 3       4    akshay.yadav.cse.2021@miet.ac.in         AKSHAY YADAV
# 4       5      aman.rathi.cse.2021@miet.ac.in           Aman Rathi
# ..    ...                                 ...                  ...
# 304   305     vineet.kumar.it.2021@miet.ac.in  Vineet Kumar Singh
# 305   306    vineet.panwar.it.2021@miet.ac.in       Vineet panwar
# 306   307     vipul.bansal.it.2021@miet.ac.in        Vipul Bansal
# 307   308      vipul.tyagi.it.2021@miet.ac.in          Vipul Tyagi
# 308   309            nancys28072003@gmail.com               Nainsi
#
#      mobile no. parents mobile no.    Roll Number Course / Branch  \
# 0    7037941222         7037941222  2100680100063   B.Tech ( CSE)
# ...

# %%
df2=df[df['Username'].str.contains('cseds')]

# %%
df2
# Out:
#      s.no                                Username               Name  \
# 237   238     nikita.tiwari.cseds.2021@miet.ac.in      NIKITA TIWARI
# 238   239    aman.upadhayay.cseds.2021@miet.ac.in     Aman Upadhayay
# 239   240      aastha.malik.cseds.2021@miet.ac.in       Aastha Malik
# 240   241      aditya.dabas.cseds.2021@miet.ac.in      Aditya dabas
# 241   242      aman.chhabra.cseds.2021@miet.ac.in       Aman chhabra
# 242   243     ananya.dudeja.cseds.2021@miet.ac.in      Ananya Dudeja
# 243   244      arthav.kumar.cseds.2021@miet.ac.in      Arthav Kumar
# 244   245   ayush.chaudhary.cseds.2021@miet.ac.in   Ayush Chaudhary
# 246   247     krishna.kumar.cseds.2021@miet.ac.in     Krishna kumar
# 247   248     lavnesh.kumar.cseds.2021@miet.ac.in      Lavnesh kumar
# 248   249     nipun.singhal.cseds.2021@miet.ac.in      Nipun Singhal
# 249   250   samarth.kaushik.cseds.2021@miet.ac.in    Samarth Kaushik
# 250   251  shobit.choudhary.cseds.2021@miet.ac.in  Shobit Choudhary
# ...

# %%
df3=df2.groupby('profile')['Username'].apply(list)

# %%
df2.columns
# Out:
# Index(['s.no', 'Username', 'Name', 'mobile no.', 'parents mobile no.',
#        'Roll Number', 'Course / Branch', 'profile', 'Gender\n', 'LOCATION',
#        'Passing Year', ' X % ', ' XII % ', 'Diploma%',
#        'B.Tech CSIT/All Allied branches/ UG%', 'Name of the college',
#        'Do you have any active backlog?', 'Your home town?', 'Upload Resume'],
#       dtype='object')

# %%
df3=pd.DataFrame(df3)
df3
# Out:
#                                                                           Username
# profile
# AI/ML Engineer                   [aastha.malik.cseds.2021@miet.ac.in, lavnesh.k...
# Business Development Excecutive            [siddhant.kumar.csedsl.2021@miet.ac.in]
# Data Analyst                     [nikita.tiwari.cseds.2021@miet.ac.in, aditya.d...
# IT Consultant                    [aman.upadhayay.cseds.2021@miet.ac.in, arthav....
# Python Developer                 [aman.chhabra.cseds.2021@miet.ac.in, ayush.cha...

# %%
df4=df['Username'].str.split('.')

# %%
df4=pd.DataFrame(df4)

# %%
df4=lambda x:v[0]
# Out:
#   Cell In[95], line 1
#     df4=lambda x:v[0] for value in df4['Username']
#                       ^
# SyntaxError: invalid syntax
